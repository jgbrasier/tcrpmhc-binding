# %%
import numpy as np
import pandas as pd

# %%
blosum50 = pd.read_csv('data/encoding/blosum50.matrix')

# %%
blosum50
# Out:
#     A   "R"   "N"   "D"   "C"   "Q"   "E"   "G"   "H"   "I"  ...   "S"   "T"  \
# 0   5    -2    -1    -2    -1    -1    -1     0    -2    -1  ...     1     0
# 1  -2     7    -1    -2    -4     1     0    -3     0    -4  ...    -1    -1
# 2  -1    -1     7     2    -2     0     0     0     1    -3  ...     1     0
# 3  -2    -2     2     8    -4     0     2    -1    -1    -4  ...     0    -1
# 4  -1    -4    -2    -4    13    -3    -3    -3    -3    -2  ...    -1    -1
# 5  -1     1     0     0    -3     7     2    -2     1    -3  ...     0    -1
# 6  -1     0     0     2    -3     2     6    -3     0    -4  ...    -1    -1
# 7   0    -3     0    -1    -3    -2    -3     8    -2    -4  ...     0    -2
# 8  -2     0     1    -1    -3     1     0    -2    10    -4  ...    -1    -2
# 9  -1    -4    -3    -4    -2    -3    -4    -4    -4     5  ...    -3    -1
# 10 -2    -3    -4    -4    -2    -2    -3    -4    -3     2  ...    -3    -1
# ...
