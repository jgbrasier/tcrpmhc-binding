# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Data Load & Preprocess

# %%
vdjdb_raw = pd.read_csv('data/raw/vdjdb.tsv', sep='\t')
iedb_raw = pd.read_csv('data/raw/iedb.csv')
tcr_train = pd.read_csv('data/net_tcr/train_ab_95_alphabeta.csv')
# Out:
# /var/folders/w1/mbcsphtx2xz1xqrls0v3d6r80000gn/T/ipykernel_72478/1976341293.py:2: DtypeWarning: Columns (8,10,12,16,17,18,19,20,21,22,23,24,26,31,32,37,38,45,46,47,48,49,50,51,52,53,60,61,66,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   iedb_raw = pd.read_csv('data/raw/iedb.csv')

# %% [markdown]
# ## IEDB

# %%
print(iedb_raw.columns)
print(iedb_raw.shape)
# Out:
# Index(['Group Receptor ID', 'Receptor ID', 'Reference IRI', 'Epitope IRI',
#        'Description', 'Antigen', 'Organism', 'Response Type', 'Assay IDs',
#        'MHC Allele Names', 'Reference Name', 'STABLE ID', 'Synonyms',
#        'Receptor Type', 'Chain 1 Type', 'Chain 1 Species',
#        'Chain 1 Nucleotide', 'Curated Chain 1 V Gene',
#        'Calculated Chain 1 V Gene', 'Curated Chain 1 D Gene',
#        'Calculated Chain 1 D Gene', 'Curated Chain 1 J Gene',
#        'Calculated Chain 1 J Gene', 'Chain 1 Full Sequence',
#        'Chain 1 Accession', 'Chain 1 CDR3 Curated', 'Chain 1 CDR3 Calculated',
#        'Chain 1 CDR3 Start Curated', 'Chain 1 CDR3 End Curated',
#        'Chain 1 CDR3 Start Calculated', 'Chain 1 CDR3 End Calculated',
#        'Chain 1 CDR1 Curated', 'Chain 1 CDR1 Calculated',
#        'Chain 1 CDR1 Start Curated', 'Chain 1 CDR1 End Curated',
#        'Chain 1 CDR1 Start Calculated', 'Chain 1 CDR1 End Calculated',
#        'Chain 1 CDR2 Curated', 'Chain 1 CDR2 Calculated',
#        'Chain 1 CDR2 Start Curated', 'Chain 1 CDR2 End Curated',
#        'Chain 1 CDR2 Start Calculated', 'Chain 1 CDR2 End Calculated',
#        'Chain 2 Type', 'Chain 2 Species', 'Chain 2 Nucleotide',
#        'Curated Chain 2 V Gene', 'Calculated Chain 2 V Gene',
#        'Curated Chain 2 D Gene', 'Calculated Chain 2 D Gene',
#        'Curated Chain 2 J Gene', 'Calculated Chain 2 J Gene',
#        'Chain 2 Full Sequence', 'Chain 2 Accession', 'Chain 2 CDR3 Curated',
#        'Chain 2 CDR3 Calculated', 'Chain 2 CDR3 Start Curated',
#        'Chain 2 CDR3 End Curated', 'Chain 2 CDR3 Start Calculated',
#        'Chain 2 CDR3 End Calculated', 'Chain 2 CDR1 Curated',
#        'Chain 2 CDR1 Calculated', 'Chain 2 CDR1 Start Curated',
#        'Chain 2 CDR1 End Curated', 'Chain 2 CDR1 Start Calculated',
#        'Chain 2 CDR1 End Calculated', 'Chain 2 CDR2 Curated',
#        'Chain 2 CDR2 Calculated', 'Chain 2 CDR2 Start Curated',
#        'Chain 2 CDR2 End Curated', 'Chain 2 CDR2 Start Calculated',
#        'Chain 2 CDR2 End Calculated'],
#       dtype='object')
# (23040, 72)

# %%
subset = ['Chain 1 CDR3 Curated', 'Chain 2 CDR3 Curated']
iedb = iedb_raw.dropna(subset=subset)
iedb
# Out:
#        Group Receptor ID  Receptor ID                          Reference IRI  \
# 0                     47           57  http://www.iedb.org/reference/1004539
# 64                   110          139  http://www.iedb.org/reference/1031961
# 66                   111          140  http://www.iedb.org/reference/1031961
# 77                   117          151  http://www.iedb.org/reference/1012513
# 127                  619          803  http://www.iedb.org/reference/1012513
# ...                  ...          ...                                    ...
# 23035             191328       212191  http://www.iedb.org/reference/1040829
# 23036             191330       212193  http://www.iedb.org/reference/1040280
# 23037             191332       212195  http://www.iedb.org/reference/1040829
# 23038             191334       212197  http://www.iedb.org/reference/1040280
# 23039             191335       212198  http://www.iedb.org/reference/1040280
#
#                                Epitope IRI Description  \
# 0        http://www.iedb.org/epitope/69921   VMAPRTLIL
# 64       http://www.iedb.org/epitope/37257   LLFGYPVYV
# 66       http://www.iedb.org/epitope/37257   LLFGYPVYV
# 77       http://www.iedb.org/epitope/59278   SLLMWITQC
# 127        http://www.iedb.org/epitope/155   AAGIGILTV
# ...                                    ...         ...
# 23035  http://www.iedb.org/epitope/1310756   QYIKWPWYI
# 23036  http://www.iedb.org/epitope/1858285   KPVETSNSF
# 23037    http://www.iedb.org/epitope/60242   SPRWYFYYL
# 23038    http://www.iedb.org/epitope/70898   VSDGGPNLY
# 23039    http://www.iedb.org/epitope/38043   LMIERFVSL
#
#                                                  Antigen  \
# 0      HLA class I histocompatibility antigen, Cw-3 a...
# 64                         transcriptional activator Tax
# 66                         transcriptional activator Tax
# 77                               Cancer/testis antigen 1
# 127             Melanoma antigen recognized by T-cells 1
# ...                                                  ...
# 23035                                 Spike glycoprotein
# 23036                          Replicase polyprotein 1ab
# 23037                                      Nucleoprotein
# 23038  RNA-directed RNA polymerase subunit P1 (Polyme...
# 23039                          Replicase polyprotein 1ab
#
#                                                 Organism Response Type  \
# 0                                   Homo sapiens (human)        T cell
# 64     Human T-cell leukemia virus type I (Human T ce...        T cell
# 66     Human T-cell leukemia virus type I (Human T ce...        T cell
# 77                                  Homo sapiens (human)        T cell
# 127                                 Homo sapiens (human)        T cell
# ...                                                  ...           ...
# 23035                                          SARS-CoV2        T cell
# 23036                                          SARS-CoV2        T cell
# 23037                                          SARS-CoV2        T cell
# 23038                                  Influenza A virus        T cell
# 23039                                          SARS-CoV2        T cell
#
#                                                Assay IDs  \
# 0                                       1548960, 1583178
# 64                             4563281, 4563282, 4563283
# 66                             4563409, 4563445, 4563612
# 77     3480611, 3480614, 3480615, 3480625, 3480629, 3...
# 127                   3791903, 3791906, 3791916, 3791919
# ...                                                  ...
# 23035                                           21117414
# 23036                                           18141786
# 23037                                           21117415
# 23038                                           18141470
# 23039                                           18141087
#
#                MHC Allele Names  ... Chain 2 CDR1 Start Curated  \
# 0      HLA-E*01:01, HLA-E*01:03  ...                        NaN
# 64                  HLA-A*02:01  ...                        NaN
# 66                  HLA-A*02:01  ...                        NaN
# 77                  HLA-A*02:01  ...                        NaN
# 127                 HLA-A*02:01  ...                        NaN
# ...                         ...  ...                        ...
# 23035               HLA-A*24:02  ...                        NaN
# 23036               HLA-B*07:02  ...                        NaN
# 23037               HLA-B*07:02  ...                        NaN
# 23038               HLA-A*01:01  ...                        NaN
# 23039               HLA-A*02:01  ...                        NaN
#
#        Chain 2 CDR1 End Curated Chain 2 CDR1 Start Calculated  \
# 0                           NaN                          25.0
# 64                          NaN                          27.0
# 66                          NaN                          27.0
# 77                          NaN                          25.0
# 127                         NaN                          27.0
# ...                         ...                           ...
# 23035                       NaN                           NaN
# 23036                       NaN                           NaN
# 23037                       NaN                           NaN
# 23038                       NaN                           NaN
# 23039                       NaN                           NaN
#
#       Chain 2 CDR1 End Calculated Chain 2 CDR2 Curated  \
# 0                            29.0                  NaN
# 64                           31.0                  NaN
# 66                           31.0                  NaN
# 77                           29.0               SVGAGI
# 127                          31.0               SYGVKD
# ...                           ...                  ...
# 23035                         NaN                  NaN
# 23036                         NaN                  NaN
# 23037                         NaN                  NaN
# 23038                         NaN                  NaN
# 23039                         NaN                  NaN
#
#        Chain 2 CDR2 Calculated Chain 2 CDR2 Start Curated  \
# 0                       FVKESK                        NaN
# 64                      SVGAGI                        NaN
# 66                      SVGAGI                        NaN
# 77                      SVGAGI                        NaN
# 127                     SYGVKD                        NaN
# ...                        ...                        ...
# 23035                      NaN                        NaN
# 23036                      NaN                        NaN
# 23037                      NaN                        NaN
# 23038                      NaN                        NaN
# 23039                      NaN                        NaN
#
#       Chain 2 CDR2 End Curated Chain 2 CDR2 Start Calculated  \
# 0                          NaN                          47.0
# 64                         NaN                          49.0
# 66                         NaN                          49.0
# 77                         NaN                          47.0
# 127                        NaN                          49.0
# ...                        ...                           ...
# 23035                      NaN                           NaN
# 23036                      NaN                           NaN
# 23037                      NaN                           NaN
# 23038                      NaN                           NaN
# 23039                      NaN                           NaN
#
#       Chain 2 CDR2 End Calculated
# 0                            52.0
# 64                           54.0
# 66                           54.0
# 77                           52.0
# 127                          54.0
# ...                           ...
# 23035                         NaN
# 23036                         NaN
# 23037                         NaN
# 23038                         NaN
# 23039                         NaN
#
# [22771 rows x 72 columns]

# %%
iedb[['Chain 1 CDR3 Curated', 'Chain 2 CDR3 Curated']]
# Out:
#       Chain 1 CDR3 Curated Chain 2 CDR3 Curated
# 0             IVVRSSNTGKLI           ASSQDRDTQY
# 64           CAVTTDSWGKLQF     CASRPGLAGGRPEQYF
# 66           CAVTTDSWGKLQF     CASRPGLMSAQPEQYF
# 77         CAVRPTSGGSYIPTF       CASSYVGNTGELFF
# 127            CAGGTGNQFYF       CAISEVGVGQPQHF
# ...                    ...                  ...
# 23035      CAMSPFSGSARQLTF       CSVLWSGREGEQFF
# 23036        CGAGETSGSRLTF       CSVNLGGPTDTQYF
# 23037        CLVGNTGGFKTIF        CSVPDRGNTEAFF
# 23038      CAPSRHAGNNRKLIW        CSVQGGTNEKLFF
# 23039        CAASPFTGNQFYF         CSVQGSSYEQYF
#
# [22771 rows x 2 columns]

# %%
iedb_base_cols = ['Group Receptor ID', 'Receptor ID', 'Reference IRI', 'Epitope IRI',
       'Description', 'Antigen', 'Organism', 'Response Type', 'Assay IDs',
       'MHC Allele Names', 'Reference Name', 'STABLE ID', 'Synonyms',
       'Receptor Type']

iedb_a_cols = [col for col in iedb.columns if "Chain 1" in col]
iedb_b_cols = [col for col in iedb.columns if "Chain 2" in col]

iedb_a = iedb[iedb_base_cols + iedb_a_cols]
iedb_b = iedb[iedb_base_cols + iedb_b_cols]

# %%
iedb_a_merge_curated = pd.merge(tcr_train['CDR3a'], iedb_a, how='inner', left_on='CDR3a', right_on='Chain 1 CDR3 Curated')
iedb_a_merge_calculated = pd.merge(tcr_train['CDR3a'], iedb_a, how='inner', left_on='CDR3a', right_on='Chain 1 CDR3 Calculated')
print('CDR3a IEDB curated:', iedb_a_merge_curated.shape)
print('CDR3a IEDB calculated:', iedb_a_merge_calculated.shape)

iedb_b_merge_curated = pd.merge(tcr_train['CDR3b'], iedb_b, how='inner', left_on='CDR3b', right_on='Chain 2 CDR3 Curated')
iedb_b_merge_calculated = pd.merge(tcr_train['CDR3b'], iedb_b, how='inner', left_on='CDR3b', right_on='Chain 2 CDR3 Calculated')
print('CDR3b IEDB curated:', iedb_b_merge_curated.shape)
print('CDR3b IEDB calculated:', iedb_b_merge_calculated.shape)
# Out:
# CDR3a IEDB curated: (1951, 44)
# CDR3a IEDB calculated: (505, 44)
# CDR3b IEDB curated: (2952, 44)
# CDR3b IEDB calculated: (42066, 44)
